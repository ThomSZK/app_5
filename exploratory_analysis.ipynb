# %%
import pandas as pd
import numpy as np
import json
# Show all columns without truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ## Vagas analysis

# %%
with open('data/vagas/vagas.json', 'r') as f:
    data = json.load(f)

# Flatten JSON
flattened_data = []
for key, value in data.items():
    row = {"id": key}
    for section, details in value.items():
        for sub_key, sub_value in details.items():
            row[f"{section}_{sub_key}"] = sub_value
    flattened_data.append(row)

vagas = pd.DataFrame(flattened_data)

# %%
vagas.sample(5)
# Out:
#           id informacoes_basicas_data_requicisao  \
# 2957   10224                          09-09-2022
# 12413   1033                          11-07-2019
# 6428   13797                          12-11-2024
# 4630    8093                          18-01-2022
# 8766    1479                          27-09-2019
#
#       informacoes_basicas_limite_esperado_para_contratacao  \
# 2957                                            07-10-2022
# 12413                                           00-00-0000
# 6428                                            25-11-2024
# 4630                                            00-00-0000
# 8766                                            00-00-0000
#
#                informacoes_basicas_titulo_vaga informacoes_basicas_vaga_sap  \
# 2957                      SAP MM Sr - 526/2022                          Não
# 12413                         3770607 - SAP MM                          Não
# 6428   Assistente Administrativo Sênior (Rede)                          Não
# ...

# %%
vagas.loc[vagas['id'] == '10976']
# Out:
#          id informacoes_basicas_data_requicisao  \
# 2221  10976                          01-02-2023
#
#      informacoes_basicas_limite_esperado_para_contratacao  \
# 2221                                           01-02-2023
#
#      informacoes_basicas_titulo_vaga informacoes_basicas_vaga_sap  \
# 2221                    Analista NOC                          Não
#
#      informacoes_basicas_cliente informacoes_basicas_solicitante_cliente  \
# 2221               Porter-Wilson                    Dr. Alexandre Barros
#
#      informacoes_basicas_empresa_divisao informacoes_basicas_requisitante  \
# 2221                  Decision São Paulo                  Cecília Freitas
#
#      informacoes_basicas_analista_responsavel  \
# 2221                             Luna Correia
#
#      informacoes_basicas_tipo_contratacao  \
# 2221                CLT Full, PJ/Autônomo
#
#      informacoes_basicas_prazo_contratacao informacoes_basicas_objetivo_vaga  \
# ...

# %%
vagas['informacoes_basicas_vaga_sap'].value_counts(dropna=False)
# Out:
# informacoes_basicas_vaga_sap
# Não    13388
# Sim      693
# Name: count, dtype: int64

# %%
vagas['informacoes_basicas_cliente'].value_counts(dropna=False)
# Out:
# informacoes_basicas_cliente
# Nelson-Page                 3250
# Miller-Curry                1785
# Morris, Moran and Dodson    1498
# Morrison Ltd                1438
# Barnes-Woods                 833
#                             ...
# Davis LLC                      1
# Johnson-Gomez                  1
# Allen, Brown and Johnson       1
# Meyer-Mcdonald                 1
# Ramos, Ponce and Landry        1
# Name: count, Length: 112, dtype: int64

# %%
vagas['perfil_vaga_outro_idioma'].value_counts(dropna=False)
# Out:
# perfil_vaga_outro_idioma
#                            13708
# Português Básico             167
# Português Fluente             95
# Básico                        41
# Português Avançado            17
# Nenhum                        14
# Português                     10
# Mandarim - Desejável           9
# Francês Fluente                7
# Português Intermediário        4
# Alemão Avançado                2
# Avançado                       2
# Mandarim ou Russo              1
# Fluente                        1
# Francês Básico                 1
# Alemão Fluente                 1
# Francês Intermediário          1
# Name: count, dtype: int64

# %%
vagas['perfil_vaga_nivel_ingles'].value_counts(dropna=False)
# Out:
# perfil_vaga_nivel_ingles
# Básico           4955
# Nenhum           3712
# Avançado         2526
# Fluente          1457
# Intermediário    1240
# Técnico           191
# Name: count, dtype: int64

# %%
vagas['perfil_vaga_nivel_espanhol'].value_counts(dropna=False)
# Out:
# perfil_vaga_nivel_espanhol
# Nenhum           6152
# Básico           5821
#                  1304
# Avançado          332
# Intermediário     234
# Fluente           227
# Técnico            11
# Name: count, dtype: int64

# %%
vagas['perfil_vaga_nivel profissional'].value_counts(dropna=False)
# Out:
# perfil_vaga_nivel profissional
# Sênior                    5297
# Analista                  5282
# Pleno                     2124
# Júnior                     637
# Especialista               397
# Assistente                 145
# Gerente                     81
# Líder                       62
# Supervisor                  22
# Coordenador                 21
# Auxiliar                     7
# Aprendiz                     3
# Trainee                      2
# Técnico de Nível Médio       1
# Name: count, dtype: int64

# %%
vagas['perfil_vaga_nivel_academico'].value_counts(dropna=False)
# Out:
# perfil_vaga_nivel_academico
# Ensino Superior Completo       10992
# Ensino Médio Completo           1459
# Ensino Superior Cursando         701
# Ensino Técnico Completo          657
# Ensino Superior Incompleto       174
# Pós Graduação Completo            51
# Pós Graduação Cursando            13
# Ensino Médio Incompleto            9
# Pós Graduação Incompleto           7
# Ensino Fundamental Completo        6
# Ensino Técnico Incompleto          3
# Ensino Técnico Cursando            3
# Mestrado Completo                  3
# Doutorado Cursando                 1
# Doutorado Completo                 1
# Mestrado Cursando                  1
# Name: count, dtype: int64

# %%
#will need to be cleaned to extract something useful
vagas['perfil_vaga_principais_atividades'].value_counts(dropna=False)
# Out:
# perfil_vaga_principais_atividades
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial                                                                                                                                                                                                                                                                                                                                                                               141
# ...

# %%
#will need to be cleaned to extract something useful
vagas['perfil_vaga_competencia_tecnicas_e_comportamentais'].value_counts(dropna=False)
# Out:
# perfil_vaga_competencia_tecnicas_e_comportamentais
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 125
# ...

# %% [markdown]
# ## applicants analysis

# %%
with open('data/applicants/applicants.json', 'r') as f:
    data = json.load(f)

# Flatten JSON
flattened_data = []
for key, value in data.items():
    row = {"id": key}
    for section, details in value.items():
        if isinstance(details, dict):  # Check if 'details' is a dictionary
            for sub_key, sub_value in details.items():
                row[f"{section}_{sub_key}"] = sub_value
        else:  # If 'details' is not a dictionary, add it directly
            row[section] = details
    flattened_data.append(row)

applicants = pd.DataFrame(flattened_data)

# %%
applicants.sample(2)
# Out:
#           id infos_basicas_telefone_recado infos_basicas_telefone  \
# 27213  21866                                      (11) 99689-4638
# 16790  46302                                      (87) 97674-3692
#
#       infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 27213                                            12-10-2020 22:01:45
# 16790                       Desenvolvedor        27-02-2024 14:33:05
#
#       infos_basicas_inserido_por           infos_basicas_email  \
# 27213           Juliana Cassiano      léo_monteiro@hotmail.com
# 16790          Maria Clara Pires  sr._miguel_ramos@hotmail.com
#
#          infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 27213
# 16790  Petrolina, Pernambuco
#
#       infos_basicas_data_atualizacao infos_basicas_codigo_profissional  \
# 27213            12-10-2020 22:01:45                             21866
# 16790            27-02-2024 14:33:05                             46302
#
# ...

# %%
applicants.loc[applicants['id'] == '41496']
# Out:
#           id infos_basicas_telefone_recado infos_basicas_telefone  \
# 39811  41496                                      (11) 91963-3687
#
#       infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 39811           Analista de Monitoramento        02-02-2023 15:05:09
#
#       infos_basicas_inserido_por           infos_basicas_email  \
# 39811          Melina Montenegro  sr._thales_freitas@gmail.com
#
#         infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 39811  São Paulo, São Paulo
#
#       infos_basicas_data_atualizacao infos_basicas_codigo_profissional  \
# 39811            19-04-2023 15:28:10                             41496
#
#        infos_basicas_nome informacoes_pessoais_data_aceite  \
# 39811  Sr. Thales Freitas                 19/04/2023 15:28
#
#       informacoes_pessoais_nome informacoes_pessoais_cpf  \
# 39811        Sr. Thales Freitas
#
#       informacoes_pessoais_fonte_indicacao    informacoes_pessoais_email  \
# ...

# %%
# needs to be cleaned to extract something useful
applicants['informacoes_profissionais_titulo_profissional'].value_counts(dropna=False)
# Out:
# informacoes_profissionais_titulo_profissional
#                                            14416
# Java                                         661
# Gerente de Projetos                          607
# Suporte                                      542
# Desenvolvedor                                473
#                                            ...
# Desenvolvedor Dot Net                          1
# Administrativa/logística e ou comercial        1
# BigData                                        1
# Gerente TI                                     1
# Analista de planejamento                       1
# Name: count, Length: 8368, dtype: int64

# %%
# needs to be cleaned to extract something useful
applicants['infos_basicas_objetivo_profissional'].value_counts(dropna=False)
# Out:
# infos_basicas_objetivo_profissional
#                                            14416
# Java                                         661
# Gerente de Projetos                          607
# Suporte                                      542
# Desenvolvedor                                473
#                                            ...
# Desenvolvedor Dot Net                          1
# Administrativa/logística e ou comercial        1
# BigData                                        1
# Gerente TI                                     1
# Analista de planejamento                       1
# Name: count, Length: 8368, dtype: int64

# %%
# needs to be cleaned to extract something useful
applicants['informacoes_profissionais_area_atuacao'].value_counts(dropna=False)
# Out:
# informacoes_profissionais_area_atuacao
#                                                                                                                                                                                                                                             35731
# TI - Desenvolvimento/Programação                                                                                                                                                                                                             1086
# Administrativa                                                                                                                                                                                                                                907
# ...

# %%
# needs to be cleaned to extract something useful
applicants['informacoes_profissionais_conhecimentos_tecnicos'].value_counts(dropna=False)
# Out:
# informacoes_profissionais_conhecimentos_tecnicos
# ...

# %%
applicants['informacoes_profissionais_nivel_profissional'].value_counts(dropna=False)
# Out:
# informacoes_profissionais_nivel_profissional
#                           42402
# Sênior                       28
# Analista                     17
# Pleno                        11
# Especialista                  8
# Júnior                        7
# Líder                         4
# Técnico de Nível Médio        2
# Gerente                       1
# Outro                         1
# Estagiário                    1
# Name: count, dtype: int64

# %%
applicants['formacao_e_idiomas_nivel_ingles'].value_counts(dropna=False)
# Out:
# formacao_e_idiomas_nivel_ingles
#                  35638
# Intermediário     2241
# Básico            2097
# Avançado          1368
# Nenhum             594
# Fluente            544
# Name: count, dtype: int64

# %%
applicants['formacao_e_idiomas_nivel_espanhol'].value_counts(dropna=False)
# Out:
# formacao_e_idiomas_nivel_espanhol
#                  35795
# Básico            2962
# Nenhum            2246
# Intermediário      906
# Avançado           329
# Fluente            244
# Name: count, dtype: int64

# %%
applicants['formacao_e_idiomas_outro_idioma'].value_counts(dropna=False)
# Out:
# formacao_e_idiomas_outro_idioma
# -                            41069
# Português - Fluente            663
# Francês - Básico               130
# Português -                    129
# Alemão - Básico                 62
# Italiano - Básico               57
# Português - Avançado            52
# Francês - Intermediário         44
# Japonês - Básico                43
# Italiano - Intermediário        30
# Francês - Avançado              25
# Japonês - Intermediário         22
# Português - Intermediário       20
# Italiano - Avançado             19
# Alemão - Intermediário          19
# Português - Básico              17
# Francês - Fluente               15
# Italiano - Fluente              10
# Alemão - Avançado                8
# Italiano -                       8
# Português - Nenhum               6
# Japonês -                        5
# Mandarim - Básico                5
# Russo - Básico                   5
# Francês -                        4
# Alemão -                         3
# ...

# %%
# needs to be cleaned to extract something useful
applicants['cv_pt'].value_counts(dropna=False)
# Out:
# cv_pt
# ...

# %%
applicants['formacao_e_idiomas_nivel_academico'].value_counts(dropna=False)
# Out:
# formacao_e_idiomas_nivel_academico
#                                  34388
# Ensino Superior Completo          3534
# Pós Graduação Completo            1813
# Ensino Superior Cursando           897
# Ensino Superior Incompleto         417
# Ensino Médio Completo              401
# Pós Graduação Cursando             289
# Ensino Técnico Completo            225
# Mestrado Completo                  164
# Pós Graduação Incompleto           149
# Ensino Técnico Cursando             54
# Mestrado Incompleto                 33
# Mestrado Cursando                   27
# Ensino Fundamental Completo         24
# Ensino Técnico Incompleto           17
# Doutorado Completo                  12
# Ensino Médio Incompleto             10
# Ensino Médio Cursando                9
# Doutorado Incompleto                 8
# Ensino Fundamental Cursando          4
# Doutorado Cursando                   4
# Ensino Fundamental Incompleto        3
# Name: count, dtype: int64

# %% [markdown]
# ## Prospects analysis
# #### --> linker table --> no need for feature engineering

# %%
with open('data/prospects/prospects.json', 'r') as f:
    data = json.load(f)

rows = []
for job_id, job_data in data.items():
    titulo = job_data.get("titulo", "")
    modalidade = job_data.get("modalidade", "")
    prospects = job_data.get("prospects", [])
    
    for prospect in prospects:
        row = {
            "job_id": job_id,
            "titulo": titulo,
            "modalidade": modalidade,
            "nome": prospect.get("nome", ""),
            "codigo": prospect.get("codigo", ""),
            "situacao_candidado": prospect.get("situacao_candidado", ""),
            "data_candidatura": prospect.get("data_candidatura", ""),
            "ultima_atualizacao": prospect.get("ultima_atualizacao", ""),
            "comentario": prospect.get("comentario", ""),
            "recrutador": prospect.get("recrutador", "")
        }
        rows.append(row)

# Create a pandas DataFrame
prospects = pd.DataFrame(rows)

# %%
prospects.loc[prospects['job_id'] == '10976'].head()
# Out:
#       job_id        titulo modalidade                   nome codigo  \
# 41851  10976  Analista NOC             Sra. Beatriz Teixeira  41531
# 41852  10976  Analista NOC                Sr. Breno Oliveira  41527
# 41853  10976  Analista NOC                Dr. Brayan Rezende  41507
# 41854  10976  Analista NOC                Dr. Theo Fernandes  41506
# 41855  10976  Analista NOC                    Dr. Yan Vargas  41502
#
#       situacao_candidado data_candidatura ultima_atualizacao comentario  \
# 41851           Inscrito       03-02-2023
# 41852           Prospect       03-02-2023         03-02-2023
# 41853           Prospect       02-02-2023         02-02-2023
# 41854           Prospect       02-02-2023         02-02-2023
# 41855           Prospect       02-02-2023         02-02-2023
#
#               recrutador
# 41851   Caroline Machado
# 41852  Melina Montenegro
# 41853  Maria Clara Pires
# 41854  Maria Clara Pires
# 41855  Maria Clara Pires
